# %%
# Install the Pandas Library
# !pip install pandas

# %%
# Import Library

import pandas as pd

# %%
# Read the csv data file.

df=pd.read_csv("student_performance.csv")
df
# Out:
#      student_id  gender race_ethnicity parental_level_of_education  \
# 0             1  female        group B            some high school
# 1             2    male        group A                 high school
# 2             3    male        group A                some college
# 3             4  female        group B           bachelor's degree
# 4             5    male        group E                 high school
# ..          ...     ...            ...                         ...
# 299         300  female        group E                some college
# 300           1  female        group B            some high school
# 301           2    male        group A                 high school
# 302           3    male        group A                some college
# 303           4  female        group B           bachelor's degree
#
#             lunch test_preparation_course  study_hours_per_week  \
# 0    free/reduced                    none                     2
# ...

# %%
#Info
#df.info()
#Use to show the information about the table like how many rows,columns,integers it have

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   student_id                   304 non-null    int64
#  1   gender                       304 non-null    object
#  2   race_ethnicity               304 non-null    object
#  3   parental_level_of_education  303 non-null    object
#  4   lunch                        303 non-null    object
#  5   test_preparation_course      304 non-null    object
#  6   study_hours_per_week         304 non-null    int64
#  7   attendance_percentage        304 non-null    int64
#  8   math_score                   304 non-null    int64
#  9   reading_score                303 non-null    float64
#  10  writing_score                303 non-null    float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 26.3+ KB

# %%
#Describe()
#Use to describe the important Parameters about the data Its like a Summary Report of the Table
df.describe()
# Out:
#        student_id  study_hours_per_week  attendance_percentage  math_score  \
# count  304.000000            304.000000             304.000000  304.000000
# mean   148.552632              4.486842              79.513158   75.062500
# std     87.812491              2.343411               9.325070   15.445829
# min      1.000000              1.000000              45.000000   28.000000
# 25%     72.750000              2.000000              73.000000   65.000000
# 50%    148.500000              4.000000              79.000000   75.500000
# 75%    224.250000              7.000000              86.000000   87.000000
# max    300.000000              8.000000             100.000000  100.000000
#
#        reading_score  writing_score
# count     303.000000     303.000000
# mean       78.264026      77.930693
# std        14.930621      14.802625
# min        35.000000      42.000000
# 25%        69.000000      68.000000
# 50%        81.000000      79.000000
# ...

# %%
#df.head()
#Use to show the top values of the Row.It shows first five rows by defult but we can mention the numbers also.

df.head()
df.head(2)
# Out:
#    student_id  gender race_ethnicity parental_level_of_education  \
# 0           1  female        group B            some high school
# 1           2    male        group A                 high school
#
#           lunch test_preparation_course  study_hours_per_week  \
# 0  free/reduced                    none                     2
# 1  free/reduced                    none                     3
#
#    attendance_percentage  math_score  reading_score  writing_score
# 0                     78          45           64.0           54.0
# 1                     68          68           82.0           72.0

# %%
#df.tail()
#Used to show the last data of the Dataframe like bottom rows
df.tail()
df.tail(1)
df[1:1]
# Out:
# Empty DataFrame
# Columns: [student_id, gender, race_ethnicity, parental_level_of_education, lunch, test_preparation_course, study_hours_per_week, attendance_percentage, math_score, reading_score, writing_score]
# Index: []

# %%
#Use to show the columns name of the Data Frame
df.columns[3]
# Out:
# 'parental_level_of_education'

# %%
#Use to show the value of the
df.values
# Out:
# array([[1, 'female', 'group B', ..., 45, 64.0, 54.0],
#        [2, 'male', 'group A', ..., 68, 82.0, 72.0],
#        [3, 'male', 'group A', ..., 86, 85.0, 69.0],
#        ...,
#        [2, 'male', 'group A', ..., 68, 82.0, 72.0],
#        [3, 'male', 'group A', ..., 86, 85.0, 69.0],
#        [4, 'female', 'group B', ..., 72, 100.0, 100.0]], dtype=object)

# %%
#Tells about the rows and columns in the dataframe
df.size
# Out:
# 3344

# %%
#Tells about the Datatypes
df.dtypes
# Out:
# student_id                       int64
# gender                          object
# race_ethnicity                  object
# parental_level_of_education     object
# lunch                           object
# test_preparation_course         object
# study_hours_per_week             int64
# attendance_percentage            int64
# math_score                       int64
# reading_score                  float64
# writing_score                  float64
# dtype: object

# %%
#Show Indexes

df.index
# Out:
# RangeIndex(start=0, stop=304, step=1)

# %%
#Delete Values
df.drop(columns=["math_score"])
# Out:
#      student_id  gender race_ethnicity parental_level_of_education  \
# 0             1  female        group B            some high school
# 1             2    male        group A                 high school
# 2             3    male        group A                some college
# 3             4  female        group B           bachelor's degree
# 4             5    male        group E                 high school
# ..          ...     ...            ...                         ...
# 299         300  female        group E                some college
# 300           1  female        group B            some high school
# 301           2    male        group A                 high school
# 302           3    male        group A                some college
# 303           4  female        group B           bachelor's degree
#
#             lunch test_preparation_course  study_hours_per_week  \
# 0    free/reduced                    none                     2
# ...

# %%
#Delete All columns except 5

# %%
df = df.iloc[:, :5]
display(df.head())
# Out:
#    student_id  gender race_ethnicity parental_level_of_education         lunch
# 0           1  female        group B            some high school  free/reduced
# 1           2    male        group A                 high school  free/reduced
# 2           3    male        group A                some college      standard
# 3           4  female        group B           bachelor's degree      standard
# 4           5    male        group E                 high school      standard

# %%
df.loc([2,"launch"]=="free")

# %%
df
# Out:
#      student_id  gender race_ethnicity parental_level_of_education  \
# 0             1  female        group B            some high school
# 1             2    male        group A                 high school
# 2             3    male        group A                some college
# 3             4  female        group B           bachelor's degree
# 4             5    male        group E                 high school
# ..          ...     ...            ...                         ...
# 299         300  female        group E                some college
# 300           1  female        group B            some high school
# 301           2    male        group A                 high school
# 302           3    male        group A                some college
# 303           4  female        group B           bachelor's degree
#
#             lunch
# 0    free/reduced
# 1    free/reduced
# 2        standard
# 3        standard
# 4        standard
# ..            ...
# 299      standard
# ...

# %%
#Show all the null values
df.isnull().sum()
# Out:
# student_id                     0
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    1
# lunch                          1
# dtype: int64

# %%
df.isnull()
# Out:
#      student_id  gender  race_ethnicity  parental_level_of_education  lunch
# 0         False   False           False                        False  False
# 1         False   False           False                        False  False
# 2         False   False           False                        False  False
# 3         False   False           False                        False  False
# 4         False   False           False                        False  False
# ..          ...     ...             ...                          ...    ...
# 299       False   False           False                        False  False
# 300       False   False           False                        False  False
# 301       False   False           False                        False  False
# 302       False   False           False                        False  False
# 303       False   False           False                        False  False
#
# [304 rows x 5 columns]

# %%
#fillna Values

df["lunch"]=df["lunch"].fillna("free")
df.isnull().sum()
# Out:
# student_id                     0
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    1
# lunch                          0
# dtype: int64
